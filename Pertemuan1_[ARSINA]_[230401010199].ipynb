# %% [markdown]
# <a href="https://colab.research.google.com/github/Ch01pan/data-science-2026/blob/main/Pertemuan1_%5BARSINA%5D_%5B230401010199%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Python - Notebook Pertama
#PERTEMUAN 1 : Notebook Pertama Data Science

#SEL 1 : Output Sederhana
print("Hello, DataScience!")
print("Selamat datang di mata kuliah pengantar Data Science!")
# Out:
# Hello, DataScience!
# Selamat datang di mata kuliah pengantar Data Science!

# %%
#SEL 2 : Variabel dan Tipe data Dasar
nama      = "Arsina" #String
angkatan  = 2023     #Integer
ipk       = 4.0      #Float
aktif     = True    #Boolean

print(f"Nama: {nama}")
print(f"Angkatan: {angkatan}")
print(f"IPK: {ipk}")
print(f"Aktif: {aktif}")
# Out:
# Nama: Arsina
# Angkatan: 2023
# IPK: 4.0
# Aktif: True

# %%
#SEL 3 : List & Perulangan
tools = ["python","Google Colab","Jupyter Notebook","Github"]
print("\nTools Data Science yang akan kita pelajari:")
for i, tool in enumerate(tools,1):
  print(f"{i}. {tool}")
# Out:
# Tools Data Science yang akan kita pelajari:
# 1. python
# 2. Google Colab
# 3. Jupyter Notebook
# 4. Github

# %%
#SEL 4 : Fungsi Sederhana
def perkenalan (nama,prodi,angkatan) :
    """Fungsi untuk menampilkan perkenalan mahasiswa."""
    return f"Hai! Saya {nama} dari {prodi}, Angkatan {angkatan}."

hasil = perkenalan ("Arsina", "Informatika", "2023")
print (hasil)
# Out:
# Hai! Saya Arsina dari Informatika, Angkatan 2023.
